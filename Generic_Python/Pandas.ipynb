# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.2.4'

# %%
values = [1,2,3,4,5,6]
height = list(range(90,96))

# %%
emp = pd.Series(data=values, index=height, name='test')

# %%
emp
# Out:
# 90    1
# 91    2
# 92    3
# 93    4
# 94    5
# 95    6
# Name: test, dtype: int64

# %%
emp.head()
# Out:
# 90    1
# 91    2
# 92    3
# 93    4
# 94    5
# Name: test, dtype: int64

# %%
emp.tail()
# Out:
# 91    2
# 92    3
# 93    4
# 94    5
# 95    6
# Name: test, dtype: int64

# %%
emp.plot()
# Out:
# <AxesSubplot:>

# %%
emp.loc[91]
# Out:
# 2

# %%
data = {
    "NorthEast": [5.9,  5.6,  4.4,  3.8,  5.8,  4.9,  4.3,  7.1,  8.3,  7.9,  5.7],
    "MidWest": [4.5,  4.3,  3.6,  4. ,  5.7,  5.7,  4.9,  8.1,  8.7,  7.4,  5.1],
    "South": [5.3,  5.2,  4.2,  4. ,  5.7,  5.2,  4.3,  7.6,  9.1,  7.4,  5.5],
    "West": [6.6, 6., 5.2, 4.6, 6.5, 5.5, 4.5, 8.6, 10.7, 8.5, 6.1],
    "National": [5.6, 5.3, 4.3, 4.2, 5.8, 5.3, 4.6, 7.8, 9.1, 8., 5.7]
}

# %%
unemp_region = pd.DataFrame(data)

# %%
unemp_region
# Out:
#     NorthEast  MidWest  South  West  National
# 0         5.9      4.5    5.3   6.6       5.6
# 1         5.6      4.3    5.2   6.0       5.3
# 2         4.4      3.6    4.2   5.2       4.3
# 3         3.8      4.0    4.0   4.6       4.2
# 4         5.8      5.7    5.7   6.5       5.8
# 5         4.9      5.7    5.2   5.5       5.3
# 6         4.3      4.9    4.3   4.5       4.6
# 7         7.1      8.1    7.6   8.6       7.8
# 8         8.3      8.7    9.1  10.7       9.1
# 9         7.9      7.4    7.4   8.5       8.0
# 10        5.7      5.1    5.5   6.1       5.7

# %%
unemp_region.index = list(range(1995, 2017, 2))

# %%
unemp_region
# Out:
#       NorthEast  MidWest  South  West  National
# 1995        5.9      4.5    5.3   6.6       5.6
# 1997        5.6      4.3    5.2   6.0       5.3
# 1999        4.4      3.6    4.2   5.2       4.3
# 2001        3.8      4.0    4.0   4.6       4.2
# 2003        5.8      5.7    5.7   6.5       5.8
# 2005        4.9      5.7    5.2   5.5       5.3
# 2007        4.3      4.9    4.3   4.5       4.6
# 2009        7.1      8.1    7.6   8.6       7.8
# 2011        8.3      8.7    9.1  10.7       9.1
# 2013        7.9      7.4    7.4   8.5       8.0
# 2015        5.7      5.1    5.5   6.1       5.7

# %%
unemp_region.head()
# Out:
#       NorthEast  MidWest  South  West  National
# 1995        5.9      4.5    5.3   6.6       5.6
# 1997        5.6      4.3    5.2   6.0       5.3
# 1999        4.4      3.6    4.2   5.2       4.3
# 2001        3.8      4.0    4.0   4.6       4.2
# 2003        5.8      5.7    5.7   6.5       5.8

# %%
unemp_region.tail()
# Out:
#       NorthEast  MidWest  South  West  National
# 2007        4.3      4.9    4.3   4.5       4.6
# 2009        7.1      8.1    7.6   8.6       7.8
# 2011        8.3      8.7    9.1  10.7       9.1
# 2013        7.9      7.4    7.4   8.5       8.0
# 2015        5.7      5.1    5.5   6.1       5.7

# %%
unemp_region.plot()
# Out:
# <AxesSubplot:>

# %%
unemp_region['MidWest']
# Out:
# 1995    4.5
# 1997    4.3
# 1999    3.6
# 2001    4.0
# 2003    5.7
# 2005    5.7
# 2007    4.9
# 2009    8.1
# 2011    8.7
# 2013    7.4
# 2015    5.1
# Name: MidWest, dtype: float64

# %%
unemp_region['MidWest'] / 100
# Out:
# 1995    0.045
# 1997    0.043
# 1999    0.036
# 2001    0.040
# 2003    0.057
# 2005    0.057
# 2007    0.049
# 2009    0.081
# 2011    0.087
# 2013    0.074
# 2015    0.051
# Name: MidWest, dtype: float64

# %%
unemp_region['MidWest'] %100
# Out:
# 1995    4.5
# 1997    4.3
# 1999    3.6
# 2001    4.0
# 2003    5.7
# 2005    5.7
# 2007    4.9
# 2009    8.1
# 2011    8.7
# 2013    7.4
# 2015    5.1
# Name: MidWest, dtype: float64

# %%
unemp_region['West'].max()
# Out:
# 10.7

# %%
unemp_region['West'] - unemp_region['MidWest']
# Out:
# 1995    2.1
# 1997    1.7
# 1999    1.6
# 2001    0.6
# 2003    0.8
# 2005   -0.2
# 2007   -0.4
# 2009    0.5
# 2011    2.0
# 2013    1.1
# 2015    1.0
# dtype: float64

# %%
temp = unemp_region.copy()

# %%
temp
# Out:
#       NorthEast  MidWest  South  West  National
# 1995        5.9      4.5    5.3   6.6       5.6
# 1997        5.6      4.3    5.2   6.0       5.3
# 1999        4.4      3.6    4.2   5.2       4.3
# 2001        3.8      4.0    4.0   4.6       4.2
# 2003        5.8      5.7    5.7   6.5       5.8
# 2005        4.9      5.7    5.2   5.5       5.3
# 2007        4.3      4.9    4.3   4.5       4.6
# 2009        7.1      8.1    7.6   8.6       7.8
# 2011        8.3      8.7    9.1  10.7       9.1
# 2013        7.9      7.4    7.4   8.5       8.0
# 2015        5.7      5.1    5.5   6.1       5.7

# %%
temp['South'] = temp['South'].astype(str)

# %%
unemp_region.dtypes
# Out:
# NorthEast    float64
# MidWest      float64
# South        float64
# West         float64
# National     float64
# dtype: object

# %%
temp.dtypes
# Out:
# NorthEast    float64
# MidWest      float64
# South         object
# West         float64
# National     float64
# dtype: object

# %%
temp.head()
# Out:
#       NorthEast  MidWest South  West  National
# 1995        5.9      4.5   5.3   6.6       5.6
# 1997        5.6      4.3   5.2   6.0       5.3
# 1999        4.4      3.6   4.2   5.2       4.3
# 2001        3.8      4.0   4.0   4.6       4.2
# 2003        5.8      5.7   5.7   6.5       5.8

# %%
temp.sum()
# Out:
# NorthEast                                 63.7
# MidWest                                   62.0
# South        5.35.24.24.05.75.24.37.69.17.45.5
# West                                      72.8
# National                                  65.7
# dtype: object

# %%
unemp_region['mean'] = (unemp_region['NorthEast']+unemp_region['MidWest']+unemp_region['South']+unemp_region['West'])/4

# %%
unemp_region.head()
# Out:
#       NorthEast  MidWest  South  West  National   mean
# 1995        5.9      4.5    5.3   6.6       5.6  5.575
# 1997        5.6      4.3    5.2   6.0       5.3  5.275
# 1999        4.4      3.6    4.2   5.2       4.3  4.350
# 2001        3.8      4.0    4.0   4.6       4.2  4.100
# 2003        5.8      5.7    5.7   6.5       5.8  5.925

# %%
unemp_region[1995,'Meaan'] = 0.0

# %%
unemp_region.head()
# Out:
#       NorthEast  MidWest  South  West  National   mean  (1995, Meaan)
# 1995        5.9      4.5    5.3   6.6       5.6  5.575            0.0
# 1997        5.6      4.3    5.2   6.0       5.3  5.275            0.0
# 1999        4.4      3.6    4.2   5.2       4.3  4.350            0.0
# 2001        3.8      4.0    4.0   4.6       4.2  4.100            0.0
# 2003        5.8      5.7    5.7   6.5       5.8  5.925            0.0

# %%
unemp_region[1995,'mean'] = 0.0

# %%
unemp_region.head()
# Out:
#       NorthEast  MidWest  South  West  National   mean  (1995, Meaan)  \
# 1995        5.9      4.5    5.3   6.6       5.6  5.575            0.0
# 1997        5.6      4.3    5.2   6.0       5.3  5.275            0.0
# 1999        4.4      3.6    4.2   5.2       4.3  4.350            0.0
# 2001        3.8      4.0    4.0   4.6       4.2  4.100            0.0
# 2003        5.8      5.7    5.7   6.5       5.8  5.925            0.0
#
#       (1995, mean)
# 1995           0.0
# 1997           0.0
# 1999           0.0
# 2001           0.0
# 2003           0.0

# %%
unemp_region.loc[1955,'mean'] = 0.0

# %%
unemp_region.head()
# Out:
#       NorthEast  MidWest  South  West  National   mean  (1995, Meaan)  \
# 1995        5.9      4.5    5.3   6.6       5.6  5.575            0.0
# 1997        5.6      4.3    5.2   6.0       5.3  5.275            0.0
# 1999        4.4      3.6    4.2   5.2       4.3  4.350            0.0
# 2001        3.8      4.0    4.0   4.6       4.2  4.100            0.0
# 2003        5.8      5.7    5.7   6.5       5.8  5.925            0.0
#
#       (1995, mean)
# 1995           0.0
# 1997           0.0
# 1999           0.0
# 2001           0.0
# 2003           0.0

# %%
unemp_region
# Out:
#       NorthEast  MidWest  South  West  National   mean  (1995, Meaan)  \
# 1995        5.9      4.5    5.3   6.6       5.6  5.575            0.0
# 1997        5.6      4.3    5.2   6.0       5.3  5.275            0.0
# 1999        4.4      3.6    4.2   5.2       4.3  4.350            0.0
# 2001        3.8      4.0    4.0   4.6       4.2  4.100            0.0
# 2003        5.8      5.7    5.7   6.5       5.8  5.925            0.0
# 2005        4.9      5.7    5.2   5.5       5.3  5.325            0.0
# 2007        4.3      4.9    4.3   4.5       4.6  4.500            0.0
# 2009        7.1      8.1    7.6   8.6       7.8  7.850            0.0
# 2011        8.3      8.7    9.1  10.7       9.1  9.200            0.0
# 2013        7.9      7.4    7.4   8.5       8.0  7.800            0.0
# 2015        5.7      5.1    5.5   6.1       5.7  5.600            0.0
# 1955        NaN      NaN    NaN   NaN       NaN  0.000            NaN
#
#       (1995, mean)
# 1995           0.0
# ...

# %%
unemp_region.loc[1995,'mean'] = 0.0

# %%
unemp_region
# Out:
#       NorthEast  MidWest  South  West  National   mean  (1995, Meaan)  \
# 1995        5.9      4.5    5.3   6.6       5.6  0.000            0.0
# 1997        5.6      4.3    5.2   6.0       5.3  5.275            0.0
# 1999        4.4      3.6    4.2   5.2       4.3  4.350            0.0
# 2001        3.8      4.0    4.0   4.6       4.2  4.100            0.0
# 2003        5.8      5.7    5.7   6.5       5.8  5.925            0.0
# 2005        4.9      5.7    5.2   5.5       5.3  5.325            0.0
# 2007        4.3      4.9    4.3   4.5       4.6  4.500            0.0
# 2009        7.1      8.1    7.6   8.6       7.8  7.850            0.0
# 2011        8.3      8.7    9.1  10.7       9.1  9.200            0.0
# 2013        7.9      7.4    7.4   8.5       8.0  7.800            0.0
# 2015        5.7      5.1    5.5   6.1       5.7  5.600            0.0
# 1955        NaN      NaN    NaN   NaN       NaN  0.000            NaN
#
#       (1995, mean)
# 1995           0.0
# ...

# %%
names= {'NorthEast':'NE',
       'MidWest':'MW',
       'South':'S',
       'West':'W'}
unemp_region.rename(columns=names)
# Out:
#        NE   MW    S     W  National   mean  (1995, Meaan)  (1995, mean)
# 1995  5.9  4.5  5.3   6.6       5.6  0.000            0.0           0.0
# 1997  5.6  4.3  5.2   6.0       5.3  5.275            0.0           0.0
# 1999  4.4  3.6  4.2   5.2       4.3  4.350            0.0           0.0
# 2001  3.8  4.0  4.0   4.6       4.2  4.100            0.0           0.0
# 2003  5.8  5.7  5.7   6.5       5.8  5.925            0.0           0.0
# 2005  4.9  5.7  5.2   5.5       5.3  5.325            0.0           0.0
# 2007  4.3  4.9  4.3   4.5       4.6  4.500            0.0           0.0
# 2009  7.1  8.1  7.6   8.6       7.8  7.850            0.0           0.0
# 2011  8.3  8.7  9.1  10.7       9.1  9.200            0.0           0.0
# 2013  7.9  7.4  7.4   8.5       8.0  7.800            0.0           0.0
# 2015  5.7  5.1  5.5   6.1       5.7  5.600            0.0           0.0
# 1955  NaN  NaN  NaN   NaN       NaN  0.000            NaN           NaN
